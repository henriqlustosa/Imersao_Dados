# %%
# Bibliotecas importadas para o primeiro dia da Imersão de Dados
import pandas as pd

# URL da base de dados
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# Importação da base de dados com o parâmetro "compression" para descompactar o arquivo
dados = pd.read_csv(url_dados,compression = 'zip')

# %%
# Visualização dos dados
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# Formato do dataframe (linhas, colunas)
dados.shape
# Out:
# (23814, 877)

# %%
# Verificação de dados duplicados no dataframe
dados.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23809    False
# 23810    False
# 23811    False
# 23812    False
# 23813    False
# Length: 23814, dtype: bool

# %%
# Apresentação dos dois primeiros registros do dataframe
dados.head(2)
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
#
# [2 rows x 877 columns]

# %%
# Tipo de dados de uma coluna específica
type(dados['id'][1])
# Out:
# str

# %%
# Iteração no dataframe para descobrir o tipo de dados
for (columnName, columnData)in dados.iteritems():
  print( columnName, type(dados[columnName][1]))
# Out:
# id <class 'str'>
# tratamento <class 'str'>
# tempo <class 'numpy.int64'>
# dose <class 'str'>
# droga <class 'str'>
# g-0 <class 'numpy.float64'>
# g-1 <class 'numpy.float64'>
# g-2 <class 'numpy.float64'>
# g-3 <class 'numpy.float64'>
# g-4 <class 'numpy.float64'>
# g-5 <class 'numpy.float64'>
# g-6 <class 'numpy.float64'>
# g-7 <class 'numpy.float64'>
# g-8 <class 'numpy.float64'>
# g-9 <class 'numpy.float64'>
# g-10 <class 'numpy.float64'>
# g-11 <class 'numpy.float64'>
# g-12 <class 'numpy.float64'>
# g-13 <class 'numpy.float64'>
# g-14 <class 'numpy.float64'>
# g-15 <class 'numpy.float64'>
# g-16 <class 'numpy.float64'>
# g-17 <class 'numpy.float64'>
# g-18 <class 'numpy.float64'>
# g-19 <class 'numpy.float64'>
# g-20 <class 'numpy.float64'>
# g-21 <class 'numpy.float64'>
# g-22 <class 'numpy.float64'>
# g-23 <class 'numpy.float64'>
# g-24 <class 'numpy.float64'>
# g-25 <class 'numpy.float64'>
# g-26 <class 'numpy.float64'>
# g-27 <class 'numpy.float64'>
# ...

# %%
# Iteração sobre algumas colunas do dataframe
for column in dados[['id', 'tratamento','tempo','dose','droga']]:
  # Selecionando o conteúdo pelo nome da coluna utilizando o operador []
   columnSeriesObj = dados[column]
   print('Colunm Name : ', column)
   print('Column Contents : ', columnSeriesObj.values)
# Out:
# Colunm Name :  id
# Column Contents :  ['id_000644bb2' 'id_000779bfc' 'id_000a6266a' ... 'id_fffc1c3f4'
#  'id_fffcb9e7c' 'id_ffffdd77b']
# Colunm Name :  tratamento
# Column Contents :  ['com_droga' 'com_droga' 'com_droga' ... 'com_controle' 'com_droga'
#  'com_droga']
# Colunm Name :  tempo
# Column Contents :  [24 72 48 ... 48 24 72]
# Colunm Name :  dose
# Column Contents :  ['D1' 'D1' 'D1' ... 'D2' 'D1' 'D1']
# Colunm Name :  droga
# Column Contents :  ['b68db1d53' 'df89a8e5a' '18bb41b2c' ... 'cacb2b860' '8b87a7a83'
#  '972f41291']

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

###DEsafio 02: Plotar as 5 últimas linhas da tabela

###Desafio 03: Proporção das classes tratamento.

###Desafio 04: Quantas tipos de drogas foram investigados.

###Desafio 05: Procurar na documentação o método query(pandas).

###Desafio 06: Renomear as colunas tirando o hífen.

###Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

###Desafio 08: Resumo do que você aprendeu com os dados

# %%
###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
###DEsafio 02: Plotar as 5 últimas linhas da tabela
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
###Desafio 03: Proporção das classes tratamento.
dados['tratamento'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# com_droga       92.2%
# com_controle     7.8%
# Name: tratamento, dtype: object

# %%
###Desafio 04: Quantas tipos de drogas foram investigados.
dados.columns.str.match(r'(^c-*)')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
dados.columns[dados.columns.str.match(r'(c-[0-9])')]
# Out:
# Index(['c-0', 'c-1', 'c-2', 'c-3', 'c-4', 'c-5', 'c-6', 'c-7', 'c-8', 'c-9',
#        'c-10', 'c-11', 'c-12', 'c-13', 'c-14', 'c-15', 'c-16', 'c-17', 'c-18',
#        'c-19', 'c-20', 'c-21', 'c-22', 'c-23', 'c-24', 'c-25', 'c-26', 'c-27',
#        'c-28', 'c-29', 'c-30', 'c-31', 'c-32', 'c-33', 'c-34', 'c-35', 'c-36',
#        'c-37', 'c-38', 'c-39', 'c-40', 'c-41', 'c-42', 'c-43', 'c-44', 'c-45',
#        'c-46', 'c-47', 'c-48', 'c-49', 'c-50', 'c-51', 'c-52', 'c-53', 'c-54',
#        'c-55', 'c-56', 'c-57', 'c-58', 'c-59', 'c-60', 'c-61', 'c-62', 'c-63',
#        'c-64', 'c-65', 'c-66', 'c-67', 'c-68', 'c-69', 'c-70', 'c-71', 'c-72',
#        'c-73', 'c-74', 'c-75', 'c-76', 'c-77', 'c-78', 'c-79', 'c-80', 'c-81',
#        'c-82', 'c-83', 'c-84', 'c-85', 'c-86', 'c-87', 'c-88', 'c-89', 'c-90',
#        'c-91', 'c-92', 'c-93', 'c-94', 'c-95', 'c-96', 'c-97', 'c-98', 'c-99'],
#       dtype='object')

# %%
colunas = dados.columns[dados.columns.str.match(r'(c-[0-9])')]

# %%
dados_filtrados_drogas = dados[colunas]
dados_filtrados_drogas.head()
# Out:
#       c-0     c-1     c-2     c-3  ...    c-96    c-97    c-98    c-99
# 0 -0.0600  0.1083  0.6864  0.4043  ... -0.3981  0.2139  0.3801  0.4176
# 1  0.0927  0.2723  0.2772  0.7776  ...  0.1522  0.1241  0.6077  0.7371
# 2 -0.1312 -1.4640  0.3394 -1.7790  ... -0.6417 -0.2187 -1.4080  0.6931
# 3 -0.3998 -4.5520 -2.7350 -1.9630  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4 -0.3774  0.7364 -0.1659  0.2341  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 100 columns]

# %%
###Desafio 05: Procurar na documentação o método query(pandas). 

##Examples

df = pd.DataFrame({'A': range(1, 6),
                   'B': range(10, 0, -2),
                   'C C': range(10, 5, -1)})
df
# Out:
#    A   B  C C
# 0  1  10   10
# 1  2   8    9
# 2  3   6    8
# 3  4   4    7
# 4  5   2    6

# %%
df.query('A > B')
# Out:
#    A  B  C C
# 4  5  2    6

# %%
#The previous expression is equivalent to

df[df.A > df.B]
# Out:
#    A  B  C C
# 4  5  2    6

# %%
df.query('B == `C C`')
# Out:
#    A   B  C C
# 0  1  10   10

# %%
df[df.B == df['C C']]
# Out:
#    A   B  C C
# 0  1  10   10

# %%
###Desafio 06: Renomear as colunas tirando o hífen. 
dados.columns = dados.columns.str.replace(r"-", " ")

# %%
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g 0', 'g 1', 'g 2',
#        'g 3', 'g 4',
#        ...
#        'c 90', 'c 91', 'c 92', 'c 93', 'c 94', 'c 95', 'c 96', 'c 97', 'c 98',
#        'c 99'],
#       dtype='object', length=877)

# %%
###Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
dados['tempo'].value_counts().plot.barh()

plt.title('Relação de tempo da análise')
plt.xlabel('Quantidade')
plt.ylabel('Tempo')
# Out:
# Text(0, 0.5, 'Tempo')

# %%
#Solução para uma dúvida em Discord - desafio 07
import matplotlib.pyplot as plt

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.set_title("Tipos de tratamentos", fontweight="bold", color="#2874A6",fontsize=20)
ax.set_xlabel("Tratamento", fontweight="bold", fontsize="large", color="#566573")
ax.set_ylabel("Quantidade", fontweight="bold", color = "#566573", fontsize="large")


dados_trat = dados['tratamento'].value_counts()

a = dados_trat.loc['com_droga']
b = dados_trat.loc['com_controle']

ax.bar("com droga",a, label="Com droga", color="blue")
ax.bar("com controle", b, label="Com controle", color="red") 

plt.legend()

# %%
fig,ax= plt.subplots()
fig.patch.set_facecolor("#CBCDCB")


labels=['Com droga','Com tratamento']
colors=['#C44B4F','#607D86']
ax.pie(dados['tratamento'].value_counts(),labels=labels,explode=[0,0.3], colors=colors,autopct='%1.1f%%')
ax.set_title("Tratamentos",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Tratamentos')

# %%
fig,ax= plt.subplots()
fig.patch.set_facecolor("#BED7D8")

x = ['24','48','72']
colors=['#E151AF','#2BB8B3','#FED43F']
ax.bar(x,dados['tempo'].value_counts().sort_index(),width=0.8,color=colors)
ax.set_title("Tempo Experimentos",fontsize=15,color='white')
plt.xlabel("Quantidade horas")
plt.ylabel("Num Experimentos")
# Out:
# Text(0, 0.5, 'Num Experimentos')

# %%
###Desafio 08: Resumo do que você aprendeu com os dados

A
